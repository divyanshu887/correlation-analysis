# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import docx

# %%
df=pd.read_csv("Birthweight_reduced_kg_R.csv")
df.describe()

# mppwt= Mothers pre-pregnancy weight (kg)
# Birthweight = Weight of baby at time of birth(kg)
# Gestation = Gestation (weeks)
# mheight = Mothers height (cm)
# Length = Length of baby (cm)
# Out:
#                 ID     Length  Birthweight   Headcirc  Gestation     smoker  \
# count    42.000000  42.000000    42.000000  42.000000  42.000000  42.000000
# mean    894.071429  51.333333     3.312857  34.595238  39.190476   0.523810
# std     467.616186   2.935624     0.603895   2.399792   2.643336   0.505487
# min      27.000000  43.000000     1.920000  30.000000  33.000000   0.000000
# 25%     537.250000  50.000000     2.940000  33.000000  38.000000   0.000000
# 50%     821.000000  52.000000     3.295000  34.000000  39.500000   1.000000
# 75%    1269.500000  53.000000     3.647500  36.000000  41.000000   1.000000
# max    1764.000000  58.000000     4.570000  39.000000  45.000000   1.000000
#
#             mage     mnocig     mheight      mppwt       fage     fedyrs  \
# count  42.000000  42.000000   42.000000  42.000000  42.000000  42.000000
# mean   25.547619   9.428571  164.452381  57.500000  28.904762  13.666667
# ...

# %%
print("Relationship between mother’s prepregnancy weight and baby weight")
df[["Birthweight","mppwt"]].corr()
# Out:
# Relationship between mother’s prepregnancy weight and baby weight
#              Birthweight     mppwt
# Birthweight     1.000000  0.400886
# mppwt           0.400886  1.000000

# %%
print("Relationship between maternal height and baby length")
df[["mheight","Length"]].corr()
# Out:
# Relationship between maternal height and baby length
#           mheight    Length
# mheight  1.000000  0.484992
# Length   0.484992  1.000000

# %%
print("Relationship between gestation and baby weight.")
df[["Gestation","Birthweight"]].corr()
# Out:
# Relationship between gestation and baby weight.
#              Gestation  Birthweight
# Gestation     1.000000     0.708303
# Birthweight   0.708303     1.000000
